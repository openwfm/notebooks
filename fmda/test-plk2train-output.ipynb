# %%
from utils import print_dict_summary, print_first, str2time, logging_setup
import pickle
import logging
import os.path as osp
from moisture_rnn_pkl import pkl2train, run_rnn_pkl
from moisture_rnn import create_rnn_data_2

# %%
logging_setup()

# %%
file_names=['test_NW_202401.pkl','test_CA_202401.pkl']
file_dir='data'
file_paths = [osp.join(file_dir,file_name) for file_name in file_names]

# %%
# read/write control
train_file='train.pkl'
train_create=False   # if false, read
train_write=False
train_read=True

# %%
# print_dict_summary(train)

# %%
if train_create:
    logging.info('creating the training cases from files %s',file_paths)
    # osp.join works on windows too, joins paths using \ or /
    train = pkl2train(file_paths)
if train_write:
    with open(train_file, 'wb') as file:
        logging.info('Writing the rain cases into file %s',train_file)
        pickle.dump(train, file)
if train_read:
    logging.info('Reading the train cases from file %s',train_file)
    with open(train_file,'rb') as file:
        train=pickle.load(file)
# Out:
# 2024-04-17 22:53:20,170 - INFO - Reading the train cases from file train.pkl

# %%
from module_param_sets import param_sets

# %%
param_sets_keys=['1']
cases=[list(train.keys())[0]]
cases=list(train.keys())[0:10]

# %%
logging.info('Running over parameter sets %s',param_sets_keys)
logging.info('Running over cases %s',cases)
# Out:
# 2024-04-17 22:53:20,214 - INFO - Running over parameter sets ['1']
# 2024-04-17 22:53:20,215 - INFO - Running over cases ['LGFO3_202401', 'PYFO3_202401', 'RXFO3_202401', 'WMFO3_202401', 'CMFW1_202401', 'CYFW1_202401', 'CGFW1_202401', 'DIFW1_202401', 'DRYW1_202401', 'FIFW1_202401']

# %%
for i in param_sets_keys:
    for case in cases:
        logging.info('Processing case %s',case)
        print_dict_summary(train[case])
        logging.info('Misc fixes, change later')
        param_sets[i]['initialize']=False
        hours=train[case]['X'].shape[0]
        train[case]['hours']=hours
        train[case]['h2']   =hours     # not doing prediction yet                
        train[case]['Y'] = train[case]['Y'].reshape(-1, 1)
        print_dict_summary(train[case])
        run_rnn_pkl(train[case],param_sets[i])
# Out:
# 2024-04-17 22:53:20,223 - INFO - Processing case LGFO3_202401
#  id : LGFO3_202401
#  case : LGFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : LGFO3
#       lat : 45.49658
#       lon : -121.89646
#       elev : 2854
#       pixel_x : 268.34257728633906
#       pixel_y : 185.2313369395742
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.89646, max: 2854.0
# Y: NumPy array of shape (168,), min: 13.78, max: 27.3
# 2024-04-17 22:53:20,225 - INFO - Misc fixes, change later
#  id : LGFO3_202401
#  case : LGFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : LGFO3
#       lat : 45.49658
#       lon : -121.89646
#       elev : 2854
#       pixel_x : 268.34257728633906
#       pixel_y : 185.2313369395742
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.89646, max: 2854.0
# Y: NumPy array of shape (168, 1), min: 13.78, max: 27.3
#  hours : 168
#  h2 : 168
# 2024-04-17 22:53:20,226 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : LGFO3_202401
#  case : LGFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : LGFO3
#       lat : 45.49658
#       lon : -121.89646
#       elev : 2854
#       pixel_x : 268.34257728633906
#       pixel_y : 185.2313369395742
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.89646, max: 2854.0
# Y: NumPy array of shape (168, 1), min: 13.78, max: 27.3
#  hours : 168
#  h2 : 168
# 2024-04-17 22:53:20,227 - INFO - create_rnn_data_2 start
# 2024-04-17 22:53:20,228 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:53:20,239 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:53:20,240 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:53:20,258 - INFO - create_rnn_data_2 done
# 2024-04-17 22:53:20,259 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:53:20,260 - INFO - case = LGFO3_202401
# 2024-04-17 22:53:20,260 - INFO - samples = 960
# 2024-04-17 22:53:20,261 - INFO - features = 11
# 2024-04-17 22:53:20,262 - INFO - timesteps = 5
# 2024-04-17 22:53:20,262 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:53:20,264 - INFO - training = 5
# 2024-04-17 22:53:20,264 - INFO - batch_size = 32
# 2024-04-17 22:53:20,265 - INFO - initialize = False
# 2024-04-17 22:53:20,266 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 1501352107032032124
# y_train hash = 9474467689950545451
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 3.6258212312068194e+19
# 2024-04-17 22:53:31,505 - INFO - run_rnn_pkl end
# 2024-04-17 22:53:31,506 - INFO - Processing case PYFO3_202401
#  id : PYFO3_202401
#  case : PYFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : PYFO3
#       lat : 45.45861
#       lon : -121.44639
#       elev : 3362
#       pixel_x : 279.35806797999385
#       pixel_y : 189.66125870451378
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.44639, max: 3362.0
# Y: NumPy array of shape (168,), min: 17.911666666666665, max: 26.788333333333334
# 2024-04-17 22:53:31,507 - INFO - Misc fixes, change later
#  id : PYFO3_202401
#  case : PYFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : PYFO3
#       lat : 45.45861
#       lon : -121.44639
#       elev : 3362
#       pixel_x : 279.35806797999385
#       pixel_y : 189.66125870451378
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.44639, max: 3362.0
# Y: NumPy array of shape (168, 1), min: 17.911666666666665, max: 26.788333333333334
#  hours : 168
#  h2 : 168
# 2024-04-17 22:53:31,508 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : PYFO3_202401
#  case : PYFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : PYFO3
#       lat : 45.45861
#       lon : -121.44639
#       elev : 3362
#       pixel_x : 279.35806797999385
#       pixel_y : 189.66125870451378
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.44639, max: 3362.0
# Y: NumPy array of shape (168, 1), min: 17.911666666666665, max: 26.788333333333334
#  hours : 168
#  h2 : 168
# 2024-04-17 22:53:31,515 - INFO - create_rnn_data_2 start
# 2024-04-17 22:53:31,515 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:53:31,525 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:53:31,526 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:53:31,528 - INFO - create_rnn_data_2 done
# 2024-04-17 22:53:31,529 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:53:31,529 - INFO - case = PYFO3_202401
# 2024-04-17 22:53:31,530 - INFO - samples = 960
# 2024-04-17 22:53:31,531 - INFO - features = 11
# 2024-04-17 22:53:31,531 - INFO - timesteps = 5
# 2024-04-17 22:53:31,532 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:53:31,533 - INFO - training = 5
# 2024-04-17 22:53:31,533 - INFO - batch_size = 32
# 2024-04-17 22:53:31,534 - INFO - initialize = False
# 2024-04-17 22:53:31,535 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 190661886975860936
# y_train hash = 13855429698638266487
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 2.838836210811859e+19
# 2024-04-17 22:53:42,295 - INFO - run_rnn_pkl end
# 2024-04-17 22:53:42,295 - INFO - Processing case RXFO3_202401
#  id : RXFO3_202401
#  case : RXFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : RXFO3
#       lat : 45.0275
#       lon : -121.92111
#       elev : 3345
#       pixel_x : 263.12724731748335
#       pixel_y : 201.96235730919096
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.92111, max: 3345.0
# Y: NumPy array of shape (168,), min: 24.481666666666666, max: 27.5
# 2024-04-17 22:53:42,297 - INFO - Misc fixes, change later
#  id : RXFO3_202401
#  case : RXFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : RXFO3
#       lat : 45.0275
#       lon : -121.92111
#       elev : 3345
#       pixel_x : 263.12724731748335
#       pixel_y : 201.96235730919096
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.92111, max: 3345.0
# Y: NumPy array of shape (168, 1), min: 24.481666666666666, max: 27.5
#  hours : 168
#  h2 : 168
# 2024-04-17 22:53:42,298 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : RXFO3_202401
#  case : RXFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : RXFO3
#       lat : 45.0275
#       lon : -121.92111
#       elev : 3345
#       pixel_x : 263.12724731748335
#       pixel_y : 201.96235730919096
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.92111, max: 3345.0
# Y: NumPy array of shape (168, 1), min: 24.481666666666666, max: 27.5
#  hours : 168
#  h2 : 168
# 2024-04-17 22:53:42,305 - INFO - create_rnn_data_2 start
# 2024-04-17 22:53:42,305 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:53:42,317 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:53:42,318 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:53:42,320 - INFO - create_rnn_data_2 done
# 2024-04-17 22:53:42,321 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:53:42,321 - INFO - case = RXFO3_202401
# 2024-04-17 22:53:42,322 - INFO - samples = 960
# 2024-04-17 22:53:42,323 - INFO - features = 11
# 2024-04-17 22:53:42,324 - INFO - timesteps = 5
# 2024-04-17 22:53:42,324 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:53:42,325 - INFO - training = 5
# 2024-04-17 22:53:42,325 - INFO - batch_size = 32
# 2024-04-17 22:53:42,326 - INFO - initialize = False
# 2024-04-17 22:53:42,327 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 2121929566247557882
# y_train hash = 9364648143231155225
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 4.72012455544862e+19
# 2024-04-17 22:53:53,511 - INFO - run_rnn_pkl end
# 2024-04-17 22:53:53,512 - INFO - Processing case WMFO3_202401
#  id : WMFO3_202401
#  case : WMFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : WMFO3
#       lat : 45.24034
#       lon : -121.45423
#       elev : 3292
#       pixel_x : 277.0621588379795
#       pixel_y : 197.484551960177
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.45423, max: 3292.0
# Y: NumPy array of shape (168,), min: 15.32, max: 27.2
# 2024-04-17 22:53:53,513 - INFO - Misc fixes, change later
#  id : WMFO3_202401
#  case : WMFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : WMFO3
#       lat : 45.24034
#       lon : -121.45423
#       elev : 3292
#       pixel_x : 277.0621588379795
#       pixel_y : 197.484551960177
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.45423, max: 3292.0
# Y: NumPy array of shape (168, 1), min: 15.32, max: 27.2
#  hours : 168
#  h2 : 168
# 2024-04-17 22:53:53,514 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : WMFO3_202401
#  case : WMFO3_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : WMFO3
#       lat : 45.24034
#       lon : -121.45423
#       elev : 3292
#       pixel_x : 277.0621588379795
#       pixel_y : 197.484551960177
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.45423, max: 3292.0
# Y: NumPy array of shape (168, 1), min: 15.32, max: 27.2
#  hours : 168
#  h2 : 168
# 2024-04-17 22:53:53,520 - INFO - create_rnn_data_2 start
# 2024-04-17 22:53:53,521 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:53:53,532 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:53:53,533 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:53:53,534 - INFO - create_rnn_data_2 done
# 2024-04-17 22:53:53,535 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:53:53,536 - INFO - case = WMFO3_202401
# 2024-04-17 22:53:53,537 - INFO - samples = 960
# 2024-04-17 22:53:53,537 - INFO - features = 11
# 2024-04-17 22:53:53,538 - INFO - timesteps = 5
# 2024-04-17 22:53:53,539 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:53:53,539 - INFO - training = 5
# 2024-04-17 22:53:53,540 - INFO - batch_size = 32
# 2024-04-17 22:53:53,541 - INFO - initialize = False
# 2024-04-17 22:53:53,541 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 4582348165034223962
# y_train hash = 3880555703181078644
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 5.152548513938843e+19
# 2024-04-17 22:54:04,228 - INFO - run_rnn_pkl end
# 2024-04-17 22:54:04,228 - INFO - Processing case CMFW1_202401
#  id : CMFW1_202401
#  case : CMFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : CMFW1
#       lat : 48.025
#       lon : -120.24139
#       elev : 3156
#       pixel_x : 333.43876951430195
#       pixel_y : 104.33246484926428
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -131.36117214855705, max: 3156.0
# Y: NumPy array of shape (168,), min: 13.343333333333334, max: 27.4
# 2024-04-17 22:54:04,229 - INFO - Misc fixes, change later
#  id : CMFW1_202401
#  case : CMFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : CMFW1
#       lat : 48.025
#       lon : -120.24139
#       elev : 3156
#       pixel_x : 333.43876951430195
#       pixel_y : 104.33246484926428
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -131.36117214855705, max: 3156.0
# Y: NumPy array of shape (168, 1), min: 13.343333333333334, max: 27.4
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:04,230 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : CMFW1_202401
#  case : CMFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : CMFW1
#       lat : 48.025
#       lon : -120.24139
#       elev : 3156
#       pixel_x : 333.43876951430195
#       pixel_y : 104.33246484926428
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -131.36117214855705, max: 3156.0
# Y: NumPy array of shape (168, 1), min: 13.343333333333334, max: 27.4
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:04,237 - INFO - create_rnn_data_2 start
# 2024-04-17 22:54:04,238 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:54:04,248 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:54:04,249 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:54:04,251 - INFO - create_rnn_data_2 done
# 2024-04-17 22:54:04,252 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:54:04,252 - INFO - case = CMFW1_202401
# 2024-04-17 22:54:04,253 - INFO - samples = 960
# 2024-04-17 22:54:04,253 - INFO - features = 11
# 2024-04-17 22:54:04,254 - INFO - timesteps = 5
# 2024-04-17 22:54:04,255 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:54:04,256 - INFO - training = 5
# 2024-04-17 22:54:04,256 - INFO - batch_size = 32
# 2024-04-17 22:54:04,257 - INFO - initialize = False
# 2024-04-17 22:54:04,258 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 3303409268332387603
# y_train hash = 6129352799246436812
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 4.615216123924888e+19
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa2d85ba4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2024-04-17 22:54:15,046 - WARNING - 5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa2d85ba4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2024-04-17 22:54:15,223 - INFO - run_rnn_pkl end
# 2024-04-17 22:54:15,224 - INFO - Processing case CYFW1_202401
#  id : CYFW1_202401
#  case : CYFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : CYFW1
#       lat : 45.92944
#       lon : -122.20278
#       elev : 2592
#       pixel_x : 264.8956015271882
#       pixel_y : 167.51925366712777
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -122.20278, max: 2592.0
# Y: NumPy array of shape (168,), min: 11.42, max: 27.2
# 2024-04-17 22:54:15,225 - INFO - Misc fixes, change later
#  id : CYFW1_202401
#  case : CYFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : CYFW1
#       lat : 45.92944
#       lon : -122.20278
#       elev : 2592
#       pixel_x : 264.8956015271882
#       pixel_y : 167.51925366712777
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -122.20278, max: 2592.0
# Y: NumPy array of shape (168, 1), min: 11.42, max: 27.2
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:15,226 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : CYFW1_202401
#  case : CYFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : CYFW1
#       lat : 45.92944
#       lon : -122.20278
#       elev : 2592
#       pixel_x : 264.8956015271882
#       pixel_y : 167.51925366712777
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -122.20278, max: 2592.0
# Y: NumPy array of shape (168, 1), min: 11.42, max: 27.2
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:15,231 - INFO - create_rnn_data_2 start
# 2024-04-17 22:54:15,231 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:54:15,243 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:54:15,244 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:54:15,246 - INFO - create_rnn_data_2 done
# 2024-04-17 22:54:15,246 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:54:15,247 - INFO - case = CYFW1_202401
# 2024-04-17 22:54:15,248 - INFO - samples = 960
# 2024-04-17 22:54:15,248 - INFO - features = 11
# 2024-04-17 22:54:15,249 - INFO - timesteps = 5
# 2024-04-17 22:54:15,250 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:54:15,250 - INFO - training = 5
# 2024-04-17 22:54:15,251 - INFO - batch_size = 32
# 2024-04-17 22:54:15,252 - INFO - initialize = False
# 2024-04-17 22:54:15,252 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 5813889403007477308
# y_train hash = 17631652036317375014
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 4.779289491574325e+19
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa31886c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2024-04-17 22:54:25,779 - WARNING - 6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa31886c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2024-04-17 22:54:25,944 - INFO - run_rnn_pkl end
# 2024-04-17 22:54:25,945 - INFO - Processing case CGFW1_202401
#  id : CGFW1_202401
#  case : CGFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : CGFW1
#       lat : 47.93886
#       lon : -123.06919
#       elev : 2400
#       pixel_x : 263.8581827165525
#       pixel_y : 88.9939777914783
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -123.06919, max: 2400.0
# Y: NumPy array of shape (168,), min: 12.879999999999999, max: 27.02
# 2024-04-17 22:54:25,946 - INFO - Misc fixes, change later
#  id : CGFW1_202401
#  case : CGFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : CGFW1
#       lat : 47.93886
#       lon : -123.06919
#       elev : 2400
#       pixel_x : 263.8581827165525
#       pixel_y : 88.9939777914783
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -123.06919, max: 2400.0
# Y: NumPy array of shape (168, 1), min: 12.879999999999999, max: 27.02
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:25,947 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : CGFW1_202401
#  case : CGFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : CGFW1
#       lat : 47.93886
#       lon : -123.06919
#       elev : 2400
#       pixel_x : 263.8581827165525
#       pixel_y : 88.9939777914783
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -123.06919, max: 2400.0
# Y: NumPy array of shape (168, 1), min: 12.879999999999999, max: 27.02
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:25,954 - INFO - create_rnn_data_2 start
# 2024-04-17 22:54:25,954 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:54:25,964 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:54:25,964 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:54:25,966 - INFO - create_rnn_data_2 done
# 2024-04-17 22:54:25,967 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:54:25,967 - INFO - case = CGFW1_202401
# 2024-04-17 22:54:25,968 - INFO - samples = 960
# 2024-04-17 22:54:25,969 - INFO - features = 11
# 2024-04-17 22:54:25,969 - INFO - timesteps = 5
# 2024-04-17 22:54:25,970 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:54:25,971 - INFO - training = 5
# 2024-04-17 22:54:25,971 - INFO - batch_size = 32
# 2024-04-17 22:54:25,972 - INFO - initialize = False
# 2024-04-17 22:54:25,973 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 5015687630618336830
# y_train hash = 1298031461458838505
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 3.960194447716073e+19
# 2024-04-17 22:54:36,759 - INFO - run_rnn_pkl end
# 2024-04-17 22:54:36,760 - INFO - Processing case DIFW1_202401
#  id : DIFW1_202401
#  case : DIFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : DIFW1
#       lat : 48.11556
#       lon : -120.10444
#       elev : 3566
#       pixel_x : 337.6078491086723
#       pixel_y : 101.86824962848976
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -120.10444, max: 3566.0
# Y: NumPy array of shape (168,), min: 14.98, max: 27.4
# 2024-04-17 22:54:36,761 - INFO - Misc fixes, change later
#  id : DIFW1_202401
#  case : DIFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : DIFW1
#       lat : 48.11556
#       lon : -120.10444
#       elev : 3566
#       pixel_x : 337.6078491086723
#       pixel_y : 101.86824962848976
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -120.10444, max: 3566.0
# Y: NumPy array of shape (168, 1), min: 14.98, max: 27.4
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:36,762 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : DIFW1_202401
#  case : DIFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : DIFW1
#       lat : 48.11556
#       lon : -120.10444
#       elev : 3566
#       pixel_x : 337.6078491086723
#       pixel_y : 101.86824962848976
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -120.10444, max: 3566.0
# Y: NumPy array of shape (168, 1), min: 14.98, max: 27.4
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:36,769 - INFO - create_rnn_data_2 start
# 2024-04-17 22:54:36,770 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:54:36,779 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:54:36,780 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:54:36,782 - INFO - create_rnn_data_2 done
# 2024-04-17 22:54:36,782 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:54:36,783 - INFO - case = DIFW1_202401
# 2024-04-17 22:54:36,784 - INFO - samples = 960
# 2024-04-17 22:54:36,784 - INFO - features = 11
# 2024-04-17 22:54:36,785 - INFO - timesteps = 5
# 2024-04-17 22:54:36,785 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:54:36,786 - INFO - training = 5
# 2024-04-17 22:54:36,787 - INFO - batch_size = 32
# 2024-04-17 22:54:36,787 - INFO - initialize = False
# 2024-04-17 22:54:36,788 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 15845475101956435774
# y_train hash = 7445896331484480593
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 3.174034685795823e+19
# 2024-04-17 22:54:48,025 - INFO - run_rnn_pkl end
# 2024-04-17 22:54:48,026 - INFO - Processing case DRYW1_202401
#  id : DRYW1_202401
#  case : DRYW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : DRYW1
#       lat : 47.72722
#       lon : -120.53972
#       elev : 3661
#       pixel_x : 323.39239808047864
#       pixel_y : 113.33081430103721
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -120.53972, max: 3661.0
# Y: NumPy array of shape (168,), min: 13.261666666666667, max: 27.3
# 2024-04-17 22:54:48,027 - INFO - Misc fixes, change later
#  id : DRYW1_202401
#  case : DRYW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : DRYW1
#       lat : 47.72722
#       lon : -120.53972
#       elev : 3661
#       pixel_x : 323.39239808047864
#       pixel_y : 113.33081430103721
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -120.53972, max: 3661.0
# Y: NumPy array of shape (168, 1), min: 13.261666666666667, max: 27.3
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:48,028 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : DRYW1_202401
#  case : DRYW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : DRYW1
#       lat : 47.72722
#       lon : -120.53972
#       elev : 3661
#       pixel_x : 323.39239808047864
#       pixel_y : 113.33081430103721
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -120.53972, max: 3661.0
# Y: NumPy array of shape (168, 1), min: 13.261666666666667, max: 27.3
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:48,035 - INFO - create_rnn_data_2 start
# 2024-04-17 22:54:48,035 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:54:48,045 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:54:48,046 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:54:48,047 - INFO - create_rnn_data_2 done
# 2024-04-17 22:54:48,048 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:54:48,049 - INFO - case = DRYW1_202401
# 2024-04-17 22:54:48,050 - INFO - samples = 960
# 2024-04-17 22:54:48,050 - INFO - features = 11
# 2024-04-17 22:54:48,051 - INFO - timesteps = 5
# 2024-04-17 22:54:48,051 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:54:48,052 - INFO - training = 5
# 2024-04-17 22:54:48,053 - INFO - batch_size = 32
# 2024-04-17 22:54:48,054 - INFO - initialize = False
# 2024-04-17 22:54:48,054 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 14285165999859344252
# y_train hash = 6070332255552628952
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 5.4950193581834035e+19
# 2024-04-17 22:54:58,909 - INFO - run_rnn_pkl end
# 2024-04-17 22:54:58,910 - INFO - Processing case FIFW1_202401
#  id : FIFW1_202401
#  case : FIFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : FIFW1
#       lat : 48.39236
#       lon : -121.81828
#       elev : 2160
#       pixel_x : 298.67361633406574
#       pixel_y : 80.95739289111185
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.81828, max: 2160.0
# Y: NumPy array of shape (168,), min: 25.746666666666666, max: 27.3
# 2024-04-17 22:54:58,911 - INFO - Misc fixes, change later
#  id : FIFW1_202401
#  case : FIFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : FIFW1
#       lat : 48.39236
#       lon : -121.81828
#       elev : 2160
#       pixel_x : 298.67361633406574
#       pixel_y : 80.95739289111185
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.81828, max: 2160.0
# Y: NumPy array of shape (168, 1), min: 25.746666666666666, max: 27.3
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:58,911 - INFO - run_rnn start
# resetting random seeds to 123
# case_data at entry to run_rnn_pkl
#  id : FIFW1_202401
#  case : FIFW1_202401
#  filename : data/test_NW_202401.pkl
# loc
#       STID : FIFW1
#       lat : 48.39236
#       lon : -121.81828
#       elev : 2160
#       pixel_x : 298.67361633406574
#       pixel_y : 80.95739289111185
# time: NumPy array of shape (168,), type object
# X: NumPy array of shape (168, 11), min: -121.81828, max: 2160.0
# Y: NumPy array of shape (168, 1), min: 25.746666666666666, max: 27.3
#  hours : 168
#  h2 : 168
# 2024-04-17 22:54:58,919 - INFO - create_rnn_data_2 start
# 2024-04-17 22:54:58,919 - INFO - batch_size=32
# staircase_2: shape x =  (168, 11)
# staircase_2: shape y =  (168, 1)
# staircase_2: timesteps= 5
# staircase_2: batch_size= 32
# staircase_2: return_sequences= False
# staircase_2: datapoints= 168
# staircase_2: max_batches= 33
# staircase_2: max_sequences= 1056
# staircase_2: shape x_train =  (1056, 5, 11)
# staircase_2: shape y_train =  (1056, 1)
# staircase_2: sequences generated 963
# staircase_2: batch_size= 32
# staircase_2: removing partial and empty batches at the end, keeping 960
# staircase_2: shape x_train =  (960, 5, 11)
# staircase_2: shape y_train =  (960, 1)
# 2024-04-17 22:54:58,932 - INFO - x_train shape=(960, 5, 11)
# 2024-04-17 22:54:58,933 - INFO - y_train shape=(960, 1)
# 2024-04-17 22:54:58,934 - INFO - create_rnn_data_2 done
# 2024-04-17 22:54:58,935 - INFO - train_rnn start, hours=168 fit=True
# 2024-04-17 22:54:58,936 - INFO - case = FIFW1_202401
# 2024-04-17 22:54:58,937 - INFO - samples = 960
# 2024-04-17 22:54:58,937 - INFO - features = 11
# 2024-04-17 22:54:58,938 - INFO - timesteps = 5
# 2024-04-17 22:54:58,938 - INFO - centering = [0.0, 0.0]
# 2024-04-17 22:54:58,939 - INFO - training = 5
# 2024-04-17 22:54:58,940 - INFO - batch_size = 32
# 2024-04-17 22:54:58,940 - INFO - initialize = False
# 2024-04-17 22:54:58,941 - INFO - epochs = 200
# x_train shape = (960, 5, 11)
# y_train shape = (960, 1)
# x_train hash = 13768600443164340925
# y_train hash = 7484010416843369342
# NOT initializing weights
# training in one pass, resetting state after each epoch by callback
# fitted weights hash = 5.772453251852311e+19
# 2024-04-17 22:55:10,142 - INFO - run_rnn_pkl end

# %%
logging.info('test-plk2train.ipynb done')
# Out:
# 2024-04-17 22:55:10,148 - INFO - test-plk2train.ipynb done
